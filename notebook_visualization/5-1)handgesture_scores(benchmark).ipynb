# %%
import pandas as pd
import numpy as np
import os 
import glob
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, jaccard_score

# %%
max_columns = ['Recall_max', 'Precision_max', 'F1_max',
       'Accuracy_max', 'Jaccard_max', 'Flag', 'EXP_NAME', 'CV_NUM',
       'Model_name']

# %% [markdown]
# # CAPTUM

# %% [markdown]
# ### LSTM

# %%
# Loaded from COBRA Server /benchmark_ts/2)collect_cwri_results_handgesture.ipynb

# %%
lstm_captum_results = pd.read_csv("dataset/benchmark/fingergesture/fingergesture_lstm_captum_scores.csv")
lstm_model_results = pd.read_csv("dataset/benchmark/fingergesture/fingergesture_lstm_accuracy.csv", index_col=0)

# %%
print(f"Model Accuracy ")
print(f"mean: {lstm_model_results.test_accuracy.mean()}, std: {lstm_model_results.test_accuracy.std()}")
lstm_captum_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
# Out:
# Model Accuracy
# mean: 0.6441334768568353, std: 0.020558579253542698
# /tmp/ipykernel_2874742/1283550243.py:3: FutureWarning: ['Flag', 'EXP_NAME', 'CV_NUM', 'Model_name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   lstm_captum_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
#                      Recall_max           Precision_max              F1_max  \
#                            mean       std          mean       std      mean
# EXP_NAME
# DynaMask                  0.784  0.171697      0.639970  0.105311  0.703748
# FIT                       0.648  0.071554      0.612000  0.112783  0.625131
# FeatureAblation           0.544  0.071274      0.648192  0.063898  0.590336
# GradientShap              0.652  0.030332      0.776863  0.037304  0.708696
# IntegratedGradients       0.644  0.047749      0.785711  0.038723  0.707266
# ...

# %% [markdown]
# ### TCN

# %%
tcn_captum_results = pd.read_csv("dataset/benchmark/fingergesture/fingergesture_tcn_captum_scores.csv")
tcn_model_results = pd.read_csv("dataset/benchmark/fingergesture/fingergesture_tcn_accuracy.csv", index_col=0)

# %%
print(f"Model Accuracy ")
print(f"mean: {tcn_model_results.test_accuracy.mean()}, std: {tcn_model_results.test_accuracy.std()}")
tcn_captum_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
# Out:
# Model Accuracy
# mean: 0.5681377825618945, std: 0.03950159910766929
# /tmp/ipykernel_2874742/2057382673.py:3: FutureWarning: ['Flag', 'EXP_NAME', 'CV_NUM', 'Model_name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   tcn_captum_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
#                      Recall_max           Precision_max              F1_max  \
#                            mean       std          mean       std      mean
# EXP_NAME
# DynaMask                  0.580  0.046904      0.612289  0.064780  0.593535
# FeatureAblation           0.568  0.030332      0.651691  0.040667  0.606955
# GradientShap              0.640  0.067823      0.740116  0.071690  0.684921
# IntegratedGradients       0.620  0.073485      0.725784  0.070111  0.667464
# Saliency                  0.500  0.052915      0.549651  0.026984  0.523231
# ...

# %% [markdown]
# # LAXCAT

# %%
laxcat_results = pd.read_csv("dataset/benchmark/fingergesture/fingergesture_laxcat_laxcat_scores.csv")
laxcat_model_results = pd.read_csv("dataset/benchmark/fingergesture/fingergesture_laxcat_accuracy.csv", index_col=0)

# %%
print(f"Model Accuracy ")
print(f"mean: {laxcat_model_results.test_accuracy.mean()}, std: {laxcat_model_results.test_accuracy.std()}")
laxcat_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
# Out:
# Model Accuracy
# mean: 0.5559203444564047, std: 0.06775994325441882
# /tmp/ipykernel_2755403/3302418135.py:3: FutureWarning: ['Flag', 'Model_name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   laxcat_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
#          Recall_max           Precision_max              F1_max            \
#                mean       std          mean       std      mean       std
# EXP_NAME
# 4010          0.516  0.071274      0.578545  0.067754  0.544867  0.067741
#
#          Accuracy_max           Jaccard_max           EXP_NAME      CV_NUM  \
#                  mean       std        mean       std     mean  std   mean
# EXP_NAME
# 4010             0.57  0.061237    0.376919  0.066455   4010.0  0.0    2.0
#
#
#                std
# EXP_NAME
# 4010      1.581139
