# %%
import pandas as pd
import numpy as np
import os 
import glob
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, jaccard_score

# %%
max_columns = ['Recall_max', 'Precision_max', 'F1_max',
       'Accuracy_max', 'Jaccard_max', 'Flag', 'EXP_NAME', 'CV_NUM',
       'Model_name']

# %% [markdown]
# # CATPUM

# %% [markdown]
# ### LSTM

# %%
lstm_captum_squidgame_results = pd.read_csv("dataset/benchmark/squidgame/squid_game_lstm_captum_scores.csv")
lstm_model_results = pd.read_csv("dataset/benchmark/squidgame/squid_game_lstm_accuracy.csv")

# %%
print(f"Model Accuracy ")
print(f"mean: {lstm_model_results.test_accuracy.mean()}, std: {lstm_model_results.test_accuracy.std()}")
lstm_captum_squidgame_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
# Out:
# Model Accuracy
# mean: 0.9857777777777776, std: 0.0010874210628368055
# /tmp/ipykernel_2875804/248585384.py:3: FutureWarning: ['Flag', 'EXP_NAME', 'CV_NUM', 'Model_name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   lstm_captum_squidgame_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
#                      Recall_max           Precision_max              F1_max  \
#                            mean       std          mean       std      mean
# EXP_NAME
# DynaMask               0.920000  0.038006      0.637938  0.044918  0.752755
# FIT                    0.600000  0.149071      0.666667  0.000000  0.622222
# FeatureAblation        0.566667  0.052705      0.474342  0.013234  0.515881
# GradientShap           0.826667  0.072265      0.595641  0.041335  0.692255
# IntegratedGradients    0.813333  0.064979      0.600574  0.035889  0.690764
# ...

# %% [markdown]
# ### TCN

# %%
tcn_captum_squidgame_results = pd.read_csv("dataset/benchmark/squidgame/squid_game_tcn_captum_scores.csv")
tcn_model_results = pd.read_csv("dataset/benchmark/squidgame/squid_game_tcn_accuracy.csv")

# %%
print(f"Model Accuracy ")
print(f"mean: {tcn_model_results.test_accuracy.mean()}, std: {tcn_model_results.test_accuracy.std()}")
tcn_captum_squidgame_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
# Out:
# Model Accuracy
# mean: 0.9942222222222222, std: 0.0006334307917216963
# /tmp/ipykernel_2875804/1263065171.py:3: FutureWarning: ['Flag', 'EXP_NAME', 'CV_NUM', 'Model_name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   tcn_captum_squidgame_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
#                      Recall_max           Precision_max              F1_max  \
#                            mean       std          mean       std      mean
# EXP_NAME
# DynaMask               0.500000  0.152753      0.532157  0.084858  0.492720
# FeatureAblation        0.860000  0.014907      0.645163  0.016102  0.737204
# GradientShap           0.646667  0.044721      0.554902  0.036359  0.596857
# IntegratedGradients    0.646667  0.044721      0.545933  0.030488  0.591329
# Saliency               0.333333  0.000000      0.666667  0.000000  0.444444
# ...

# %% [markdown]
# # LAXCAT

# %%
laxcat_results = pd.read_csv("dataset/benchmark/squidgame/squid_game_laxcat_laxcat_scores.csv")
laxcat_model_results = pd.read_csv("dataset/benchmark/squidgame/squid_game_laxcat_accuracy.csv")

# %%
print(f"Model Accuracy ")
print(f"mean: {laxcat_model_results.test_accuracy.mean()}, std: {laxcat_model_results.test_accuracy.std()}")
laxcat_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
# Out:
# Model Accuracy
# mean: 0.9759444444444444, std: 0.0016238718781181915
# /tmp/ipykernel_741663/3302418135.py:3: FutureWarning: ['Flag', 'Model_name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   laxcat_results.groupby('EXP_NAME')[max_columns].agg(['mean', 'std'])
#          Recall_max           Precision_max              F1_max            \
#                mean       std          mean       std      mean       std
# EXP_NAME
# 3010           0.55  0.093541      0.616176  0.120604  0.568439  0.050287
#
#          Accuracy_max           Jaccard_max           EXP_NAME      CV_NUM  \
#                  mean       std        mean       std     mean  std   mean
# EXP_NAME
# 3010         0.517778  0.070536    0.398497  0.050546   3010.0  0.0    2.0
#
#
#                std
# EXP_NAME
# 3010      1.581139
